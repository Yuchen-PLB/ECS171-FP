# %%
import pandas as pd
import operator
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import seaborn as sns

# %%
#%load_ext rpy2.ipython

# %% [markdown]
# #1.1 Data Preprocessing
# goal:  explore the dataset and transform categorical features to numerical values

# %%
#load data from google drive
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
#drive.mount('/content/gdrive')
path = '/gdrive/MyDrive/Colab Notebooks/chip_dataset.csv'
chip_dataset = pd.read_csv(path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read in the dataset locally
chip_dataset = pd.read_csv('./chip_dataset.csv')

# drop the first column which list all the indices
chip_dataset.drop('Unnamed: 0', inplace=True, axis=1)

chip_dataset
# Out:
#                       Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0         AMD Athlon 64 3500+  CPU   2007-02-20               65.0     45.0
# 1            AMD Athlon 200GE  CPU   2018-09-06               14.0     35.0
# 2        Intel Core i5-1145G7  CPU   2020-09-02               10.0     28.0
# 3       Intel Xeon E5-2603 v2  CPU   2013-09-01               22.0     80.0
# 4     AMD Phenom II X4 980 BE  CPU   2011-05-03               45.0    125.0
# ...                       ...  ...          ...                ...      ...
# 4849      NVIDIA Quadro 3000M  GPU   2011-02-22               40.0     75.0
# 4850            Intel GMA 950  GPU   2005-06-01               90.0      7.0
# 4851   NVIDIA GeForce GT 320M  GPU   2010-03-03               40.0     23.0
# 4852   NVIDIA GeForce FX 5200  GPU   2003-03-06              150.0      NaN
# 4853   NVIDIA GeForce 9300 SE  GPU   2008-06-01               65.0      NaN
#
#       Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  Vendor  \
# 0                77.0                  122.0      2200.0  Unknown     AMD
# 1               192.0                 4800.0      3200.0  Unknown     AMD
# 2                 NaN                    NaN      2600.0    Intel   Intel
# 3               160.0                 1400.0      1800.0    Intel   Intel
# 4               258.0                  758.0      3700.0  Unknown     AMD
# ...               ...                    ...         ...      ...     ...
# 4849            332.0                 1950.0       450.0     TSMC  NVIDIA
# 4850              NaN                    NaN       250.0    Intel   Intel
# 4851            100.0                  486.0       500.0     TSMC  NVIDIA
# 4852             65.0                   29.0       250.0     TSMC  NVIDIA
# 4853             86.0                  210.0       540.0     TSMC  NVIDIA
#
#       FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0             NaN          NaN          NaN
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 4849          NaN        432.0         36.0
# 4850          NaN          NaN          NaN
# 4851          NaN         52.8          NaN
# 4852          NaN          NaN          NaN
# 4853          NaN         20.8          NaN
#
# [4854 rows x 13 columns]

# %%
chip_dataset.describe(include='all')
# Out:
#                     Product  Type Release Date  Process Size (nm)  \
# count                  4854  4854         4854        4845.000000
# unique                 4278     2         1357                NaN
# top     AMD Athlon 64 3200+   GPU          NaT                NaN
# freq                     12  2662           75                NaN
# mean                    NaN   NaN          NaN          55.109598
# std                     NaN   NaN          NaN          44.998676
# min                     NaN   NaN          NaN           0.000000
# 25%                     NaN   NaN          NaN          22.000000
# 50%                     NaN   NaN          NaN          40.000000
# 75%                     NaN   NaN          NaN          90.000000
# max                     NaN   NaN          NaN         250.000000
#
#             TDP (W)  Die Size (mm^2)  Transistors (million)   Freq (MHz)  \
# count   4228.000000      4139.000000            4143.000000  4854.000000
# unique          NaN              NaN                    NaN          NaN
# top             NaN              NaN                    NaN          NaN
# freq            NaN              NaN                    NaN          NaN
# mean      81.359981       188.440445            1929.922279  1484.406057
# std       76.807808       126.189383            4044.891098  1066.701523
# min        1.000000         1.000000               8.000000   100.000000
# 25%       33.000000       104.000000             154.000000   590.000000
# 50%       65.000000       148.000000             624.000000  1073.500000
# 75%      100.000000       239.000000            1550.000000  2400.000000
# max      900.000000       826.000000           54200.000000  4700.000000
#
#        Foundry Vendor    FP16 GFLOPS   FP32 GFLOPS   FP64 GFLOPS
# count     4854   4854     536.000000   1948.000000   1306.000000
# unique      10      5            NaN           NaN           NaN
# top       TSMC    AMD            NaN           NaN           NaN
# freq      2178   1662            NaN           NaN           NaN
# mean       NaN    NaN    8397.459851   2134.756653    363.670511
# std        NaN    NaN   13799.551131   3898.431487   1145.931856
# min        NaN    NaN      10.020000     12.800000      3.600000
# 25%        NaN    NaN     768.800000    257.300000     38.295000
# 50%        NaN    NaN    2965.500000    696.000000     89.280000
# 75%        NaN    NaN   10600.000000   2116.750000    220.000000
# max        NaN    NaN  184600.000000  40000.000000  11540.000000

# %% [markdown]
# To have a brief overview of the dataset, we want to have a look of the head of the data frame and the maxium and minimum.

# %%
print("Look at the head (i.e. first 5 samples/trails) of the dataframe:")
chip_dataset.head()
# Out:
# Look at the head (i.e. first 5 samples/trails) of the dataframe:
#                    Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0      AMD Athlon 64 3500+  CPU   2007-02-20               65.0     45.0
# 1         AMD Athlon 200GE  CPU   2018-09-06               14.0     35.0
# 2     Intel Core i5-1145G7  CPU   2020-09-02               10.0     28.0
# 3    Intel Xeon E5-2603 v2  CPU   2013-09-01               22.0     80.0
# 4  AMD Phenom II X4 980 BE  CPU   2011-05-03               45.0    125.0
#
#    Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry Vendor  \
# 0             77.0                  122.0      2200.0  Unknown    AMD
# 1            192.0                 4800.0      3200.0  Unknown    AMD
# 2              NaN                    NaN      2600.0    Intel  Intel
# 3            160.0                 1400.0      1800.0    Intel  Intel
# 4            258.0                  758.0      3700.0  Unknown    AMD
#
#    FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
print("Look at minimum values for each attribute/feature:")
chip_dataset.min()
# Out:
# Look at minimum values for each attribute/feature:
# Product                  3dfx Spectre 1000
# Type                                   CPU
# Release Date                    2000-01-01
# Process Size (nm)                      0.0
# TDP (W)                                1.0
# Die Size (mm^2)                        1.0
# Transistors (million)                  8.0
# Freq (MHz)                           100.0
# Foundry                                 GF
# Vendor                                 AMD
# FP16 GFLOPS                          10.02
# FP32 GFLOPS                           12.8
# FP64 GFLOPS                            3.6
# dtype: object

# %%
print("Look at maximum values for each attribute/feature:")
chip_dataset.max()
# Out:
# Look at maximum values for each attribute/feature:
# Product                  XGI Volari V8 Ultra
# Type                                     GPU
# Release Date                             NaT
# Process Size (nm)                      250.0
# TDP (W)                                900.0
# Die Size (mm^2)                        826.0
# Transistors (million)                54200.0
# Freq (MHz)                            4700.0
# Foundry                              Unknown
# Vendor                                 Other
# FP16 GFLOPS                         184600.0
# FP32 GFLOPS                          40000.0
# FP64 GFLOPS                          11540.0
# dtype: object

# %% [markdown]
# We notic that the release Date is in the form of yyyy-mm-dd form, to make it easier to discuss, we firstly transform it to the years from 2000-1-1 and replace it to the [years from 2000].

# %%
for i in range(len(chip_dataset['Release Date'])):
  if 'Na' in chip_dataset.iat[i, 2] :
    chip_dataset.iat[i, 2] = np.NaN
  else:
    year = int(chip_dataset.iat[i, 2][0:4])-2000
    month = int(chip_dataset.iat[i, 2][5:7])/12
    day = int(chip_dataset.iat[i, 2][8:10])/365
    chip_dataset.iat[i, 2] = year+ month + day

# %%
print("Look at the head (i.e. first 5 samples/trails) of the dataframe:")
chip_dataset.head()
# Out:
# Look at the head (i.e. first 5 samples/trails) of the dataframe:
#                    Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0      AMD Athlon 64 3500+  CPU     7.221461               65.0     45.0
# 1         AMD Athlon 200GE  CPU    18.766438               14.0     35.0
# 2     Intel Core i5-1145G7  CPU    20.755479               10.0     28.0
# 3    Intel Xeon E5-2603 v2  CPU     13.75274               22.0     80.0
# 4  AMD Phenom II X4 980 BE  CPU    11.424886               45.0    125.0
#
#    Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry Vendor  \
# 0             77.0                  122.0      2200.0  Unknown    AMD
# 1            192.0                 4800.0      3200.0  Unknown    AMD
# 2              NaN                    NaN      2600.0    Intel  Intel
# 3            160.0                 1400.0      1800.0    Intel  Intel
# 4            258.0                  758.0      3700.0  Unknown    AMD
#
#    FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
print("Look at the 'Release Date' column:")
chip_dataset['Release Date']
# Out:
# Look at the 'Release Date' column:
# 0        7.221461
# 1       18.766438
# 2       20.755479
# 3        13.75274
# 4       11.424886
#           ...
# 4849    11.226941
# 4850      5.50274
# 4851    10.258219
# 4852     3.266438
# 4853      8.50274
# Name: Release Date, Length: 4854, dtype: object

# %% [markdown]
# We notice that the CPU doesn't have GFLOPS values and we decide to split the data into two subset by [Type].

# %% [markdown]
# #1.2 Data Spliting
# goal:  split data into dataframe subsets
#
# First, the data is consisted with two main category :[CPU] and [GPU], and they are evaluate by different performance. We are trying to split the data into the two subset and discuss which factors are related to the chips performance and we are trying to distinguish the relationship between them.

# %%
grouped = chip_dataset.groupby(chip_dataset['Type'])

# spilt and get the CPU dataset
CPU = grouped.get_group('CPU')
del CPU['FP16 GFLOPS']
del CPU['FP32 GFLOPS']
del CPU['FP64 GFLOPS']

# split and get the GPU dataset
GPU = grouped.get_group('GPU')

# %%
# take a look at the CPU dataset
CPU
# Out:
#                         Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0           AMD Athlon 64 3500+  CPU     7.221461               65.0     45.0
# 1              AMD Athlon 200GE  CPU    18.766438               14.0     35.0
# 2          Intel Core i5-1145G7  CPU    20.755479               10.0     28.0
# 3         Intel Xeon E5-2603 v2  CPU     13.75274               22.0     80.0
# 4       AMD Phenom II X4 980 BE  CPU    11.424886               45.0    125.0
# ...                         ...  ...          ...                ...      ...
# 2187      Intel Xeon Gold 6312U  CPU    21.349772               10.0    185.0
# 2188          AMD Ryzen 9 4900H  CPU    20.293836                7.0     54.0
# 2189     Intel Core 2 Duo E6550  CPU     7.586073               65.0     65.0
# 2190            AMD Opteron 246  CPU      5.00274               90.0     85.0
# 2191  AMD Athlon 64 X2 5000+ EE  CPU     7.169406               90.0     65.0
#
#       Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry Vendor
# 0                77.0                  122.0      2200.0  Unknown    AMD
# 1               192.0                 4800.0      3200.0  Unknown    AMD
# 2                 NaN                    NaN      2600.0    Intel  Intel
# 3               160.0                 1400.0      1800.0    Intel  Intel
# 4               258.0                  758.0      3700.0  Unknown    AMD
# ...               ...                    ...         ...      ...    ...
# 2187              NaN                    NaN      2400.0    Intel  Intel
# 2188            156.0                 9800.0      3300.0     TSMC    AMD
# 2189            143.0                  291.0      2333.0    Intel  Intel
# 2190              NaN                  106.0      2000.0  Unknown    AMD
# 2191            220.0                  154.0      2600.0  Unknown    AMD
#
# [2192 rows x 10 columns]

# %%
# take a look at the GPU dataset
GPU
# Out:
#                          Product Type Release Date  Process Size (nm)  \
# 2192          Intel Xeon E3-1275  GPU    11.341553               32.0
# 2193      Matrox Parhelia 128 MB  GPU     2.568493              150.0
# 2194  NVIDIA GeForce MX150 GP107  GPU     19.22968               14.0
# 2195               Intel GMA 500  GPU     8.255479              130.0
# 2196      ATI Radeon HD 4350 AGP  GPU     8.832192               55.0
# ...                          ...  ...          ...                ...
# 4849         NVIDIA Quadro 3000M  GPU    11.226941               40.0
# 4850               Intel GMA 950  GPU      5.50274               90.0
# 4851      NVIDIA GeForce GT 320M  GPU    10.258219               40.0
# 4852      NVIDIA GeForce FX 5200  GPU     3.266438              150.0
# 4853      NVIDIA GeForce 9300 SE  GPU      8.50274               65.0
#
#       TDP (W)  Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  \
# 2192     95.0            216.0                 1160.0       100.0    Intel
# 2193      NaN            174.0                   80.0       200.0      UMC
# 2194     25.0            132.0                 3300.0      1469.0  Samsung
# 2195      NaN              NaN                    NaN       200.0    Intel
# 2196     20.0             73.0                  242.0       600.0     TSMC
# ...       ...              ...                    ...         ...      ...
# 4849     75.0            332.0                 1950.0       450.0     TSMC
# 4850      7.0              NaN                    NaN       250.0    Intel
# 4851     23.0            100.0                  486.0       500.0     TSMC
# 4852      NaN             65.0                   29.0       250.0     TSMC
# 4853      NaN             86.0                  210.0       540.0     TSMC
#
#       Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 2192   Intel          NaN          NaN          NaN
# 2193   Other          NaN          NaN          NaN
# 2194  NVIDIA        18.38       1177.0        36.77
# 2195   Intel          NaN         12.8          NaN
# 2196     ATI          NaN         96.0          NaN
# ...      ...          ...          ...          ...
# 4849  NVIDIA          NaN        432.0        36.00
# 4850   Intel          NaN          NaN          NaN
# 4851  NVIDIA          NaN         52.8          NaN
# 4852  NVIDIA          NaN          NaN          NaN
# 4853  NVIDIA          NaN         20.8          NaN
#
# [2662 rows x 13 columns]

# %% [markdown]
# #2.1 Data Explanation

# %%
#First we want to know the data length of each category:
print("Display number of rows and columns of the CPU dataframe:")
display(CPU.shape)

print("\nDisplay number of rows and columns of the GPU dataframe:")
display(GPU.shape)

print("\nLook at the head (i.e. first 5 samples/trails) of the CPU dataframe:")
CPU.head()
# Out:
# Display number of rows and columns of the CPU dataframe:
# (2192, 10)
# Display number of rows and columns of the GPU dataframe:
# (2662, 13)
# Look at the head (i.e. first 5 samples/trails) of the CPU dataframe:
#                    Product Type Release Date  Process Size (nm)  TDP (W)  \
# 0      AMD Athlon 64 3500+  CPU     7.221461               65.0     45.0
# 1         AMD Athlon 200GE  CPU    18.766438               14.0     35.0
# 2     Intel Core i5-1145G7  CPU    20.755479               10.0     28.0
# 3    Intel Xeon E5-2603 v2  CPU     13.75274               22.0     80.0
# 4  AMD Phenom II X4 980 BE  CPU    11.424886               45.0    125.0
#
#    Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry Vendor
# 0             77.0                  122.0      2200.0  Unknown    AMD
# 1            192.0                 4800.0      3200.0  Unknown    AMD
# 2              NaN                    NaN      2600.0    Intel  Intel
# 3            160.0                 1400.0      1800.0    Intel  Intel
# 4            258.0                  758.0      3700.0  Unknown    AMD

# %%
print("Look at the head (i.e. first 5 samples/trails) of the GPU dataframe:")
GPU.head()
# Out:
# Look at the head (i.e. first 5 samples/trails) of the GPU dataframe:
#                          Product Type Release Date  Process Size (nm)  \
# 2192          Intel Xeon E3-1275  GPU    11.341553               32.0
# 2193      Matrox Parhelia 128 MB  GPU     2.568493              150.0
# 2194  NVIDIA GeForce MX150 GP107  GPU     19.22968               14.0
# 2195               Intel GMA 500  GPU     8.255479              130.0
# 2196      ATI Radeon HD 4350 AGP  GPU     8.832192               55.0
#
#       TDP (W)  Die Size (mm^2)  Transistors (million)  Freq (MHz)  Foundry  \
# 2192     95.0            216.0                 1160.0       100.0    Intel
# 2193      NaN            174.0                   80.0       200.0      UMC
# 2194     25.0            132.0                 3300.0      1469.0  Samsung
# 2195      NaN              NaN                    NaN       200.0    Intel
# 2196     20.0             73.0                  242.0       600.0     TSMC
#
#       Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 2192   Intel          NaN          NaN          NaN
# 2193   Other          NaN          NaN          NaN
# 2194  NVIDIA        18.38       1177.0        36.77
# 2195   Intel          NaN         12.8          NaN
# 2196     ATI          NaN         96.0          NaN

# %% [markdown]
# Interpretation of the CPU dataset: The data [CPU] contains 2192 observations with 10 variables/features, which are:
#
# 1.  Product: the product name of the chip.
# 2.  Type: whether the given chip is a CPU or GPU.
# 3.  Release Data: release data of the product.
# 4.  Process Size (nm): physical size of the components that makes up a chip/product measured in nm.
# 5.  TDP (W): thermal design point of the product measured in W.
# 6.  Die Size (mm^2): physical dimension of bare die measured in mm^2.
# 7.  Transistors (million): number of transistors represented in unit of million.
# 8.  Freq (MHz): frequency measured in MHz.
# 9.  Foundry: company that makes the CPU/GPU.
# 10. Vendor: seller of the CPU/GPU.

# %% [markdown]
# #2.2 Data Visualization

# %%
CPU.columns.values
# Out:
# array(['Product', 'Type', 'Release Date', 'Process Size (nm)', 'TDP (W)',
#        'Die Size (mm^2)', 'Transistors (million)', 'Freq (MHz)',
#        'Foundry', 'Vendor'], dtype=object)

# %%
_ = sns.pairplot(CPU, hue='Vendor')

# %% [markdown]
# Interpretation of the GPU dataset: The data [GPU] contains 2662 ovservations with 13 variables, which are:
#
# 1.   Product: the product name of the chip.
# 2.  Type: whether the given chip is a CPU or GPU.
# 3.  Release Data: release data of the product.
# 4.  Process Size (nm): physical size of the components that makes up a chip/product measured in nm.
# 5.  TDP (W): thermal design point of the product measured in W.
# 6.  Die Size (mm^2): physical dimension of bare die measured in mm^2.
# 7.  Transistors (million): number of transistors represented in unit of million.
# 8.  Freq (MHz): frequency measured in MHz.
# 9.  Foundry: company that makes the CPU/GPU.
# 10. Vendor: seller of the CPU/GPU.
# 11. FP16 GFLOPS: represent storage of weights, activations, and gradients during training iterations
# 12. FP32 GFLOPS: store values with larger range and higher precision than FP16 GFLOPS.
# 13. FP64 GFLOPS: store values with larger range and higher precision than FP32 GFLOPS.

# %%
GPU.columns.values
# Out:
# array(['Product', 'Type', 'Release Date', 'Process Size (nm)', 'TDP (W)',
#        'Die Size (mm^2)', 'Transistors (million)', 'Freq (MHz)',
#        'Foundry', 'Vendor', 'FP16 GFLOPS', 'FP32 GFLOPS', 'FP64 GFLOPS'],
#       dtype=object)

# %%
_ = sns.pairplot(GPU, hue='Vendor')

# %%
# visualize the correlation graph for the CPU dataset
CPU_cor = CPU.copy().corr()
CPU_cor.style.format(precision = 3).background_gradient(cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_09214_row0_col0, #T_09214_row1_col1, #T_09214_row2_col2, #T_09214_row3_col3, #T_09214_row4_col4 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_09214_row0_col1, #T_09214_row1_col0 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_09214_row0_col2, #T_09214_row2_col0 {
#   background-color: #fce2d2;
#   color: #000000;
# }
# #T_09214_row0_col3, #T_09214_row3_col0 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_09214_row0_col4, #T_09214_row4_col0 {
#   background-color: #f6af8e;
#   color: #000000;
# }
# #T_09214_row1_col2, #T_09214_row2_col1 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_09214_row1_col3, #T_09214_row3_col1 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_09214_row1_col4, #T_09214_row4_col1 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_09214_row2_col3, #T_09214_row3_col2 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_09214_row2_col4, #T_09214_row4_col2 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_09214_row3_col4, #T_09214_row4_col3 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# </style>
# <table id="T_09214_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Process Size (nm)</th>
#       <th class="col_heading level0 col1" >TDP (W)</th>
#       <th class="col_heading level0 col2" >Die Size (mm^2)</th>
#       <th class="col_heading level0 col3" >Transistors (million)</th>
#       <th class="col_heading level0 col4" >Freq (MHz)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09214_level0_row0" class="row_heading level0 row0" >Process Size (nm)</th>
#       <td id="T_09214_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_09214_row0_col1" class="data row0 col1" >-0.119</td>
#       <td id="T_09214_row0_col2" class="data row0 col2" >-0.151</td>
#       <td id="T_09214_row0_col3" class="data row0 col3" >-0.513</td>
#       <td id="T_09214_row0_col4" class="data row0 col4" >-0.361</td>
#     </tr>
#     <tr>
#       <th id="T_09214_level0_row1" class="row_heading level0 row1" >TDP (W)</th>
#       <td id="T_09214_row1_col0" class="data row1 col0" >-0.119</td>
#       <td id="T_09214_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_09214_row1_col2" class="data row1 col2" >0.411</td>
#       <td id="T_09214_row1_col3" class="data row1 col3" >0.432</td>
#       <td id="T_09214_row1_col4" class="data row1 col4" >0.333</td>
#     </tr>
#     <tr>
#       <th id="T_09214_level0_row2" class="row_heading level0 row2" >Die Size (mm^2)</th>
#       <td id="T_09214_row2_col0" class="data row2 col0" >-0.151</td>
#       <td id="T_09214_row2_col1" class="data row2 col1" >0.411</td>
#       <td id="T_09214_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_09214_row2_col3" class="data row2 col3" >0.209</td>
#       <td id="T_09214_row2_col4" class="data row2 col4" >0.262</td>
#     </tr>
#     <tr>
#       <th id="T_09214_level0_row3" class="row_heading level0 row3" >Transistors (million)</th>
#       <td id="T_09214_row3_col0" class="data row3 col0" >-0.513</td>
#       <td id="T_09214_row3_col1" class="data row3 col1" >0.432</td>
#       <td id="T_09214_row3_col2" class="data row3 col2" >0.209</td>
#       <td id="T_09214_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_09214_row3_col4" class="data row3 col4" >0.197</td>
#     </tr>
#     <tr>
#       <th id="T_09214_level0_row4" class="row_heading level0 row4" >Freq (MHz)</th>
#       <td id="T_09214_row4_col0" class="data row4 col0" >-0.361</td>
#       <td id="T_09214_row4_col1" class="data row4 col1" >0.333</td>
#       <td id="T_09214_row4_col2" class="data row4 col2" >0.262</td>
#       <td id="T_09214_row4_col3" class="data row4 col3" >0.197</td>
#       <td id="T_09214_row4_col4" class="data row4 col4" >1.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# visualize the correlation graph for the GPU dataset
GPU_cor = GPU.copy().corr()
GPU_cor.style.format(precision = 3).background_gradient(cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_0e683_row0_col0, #T_0e683_row1_col1, #T_0e683_row2_col2, #T_0e683_row3_col3, #T_0e683_row4_col4, #T_0e683_row5_col5, #T_0e683_row6_col6, #T_0e683_row7_col7 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_0e683_row0_col1, #T_0e683_row1_col0 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_0e683_row0_col2, #T_0e683_row2_col0 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_0e683_row0_col3, #T_0e683_row3_col0 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_0e683_row0_col4, #T_0e683_row4_col0 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_0e683_row0_col5, #T_0e683_row5_col0 {
#   background-color: #f5ac8b;
#   color: #000000;
# }
# #T_0e683_row0_col6, #T_0e683_row6_col0 {
#   background-color: #ea8e70;
#   color: #f1f1f1;
# }
# #T_0e683_row0_col7, #T_0e683_row7_col0 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_0e683_row1_col2, #T_0e683_row2_col1, #T_0e683_row5_col6, #T_0e683_row6_col5 {
#   background-color: #2c75b4;
#   color: #f1f1f1;
# }
# #T_0e683_row1_col3, #T_0e683_row3_col1 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_0e683_row1_col4, #T_0e683_row4_col1 {
#   background-color: #8ac0db;
#   color: #000000;
# }
# #T_0e683_row1_col5, #T_0e683_row2_col6, #T_0e683_row5_col1, #T_0e683_row6_col2 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_0e683_row1_col6, #T_0e683_row6_col1, #T_0e683_row6_col7, #T_0e683_row7_col6 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_0e683_row1_col7, #T_0e683_row7_col1 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_0e683_row2_col3, #T_0e683_row2_col5, #T_0e683_row3_col2, #T_0e683_row5_col2 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_0e683_row2_col4, #T_0e683_row4_col2 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_0e683_row2_col7, #T_0e683_row7_col2 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_0e683_row3_col4, #T_0e683_row4_col3 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_0e683_row3_col5, #T_0e683_row5_col3 {
#   background-color: #1f63a8;
#   color: #f1f1f1;
# }
# #T_0e683_row3_col6, #T_0e683_row6_col3 {
#   background-color: #185493;
#   color: #f1f1f1;
# }
# #T_0e683_row3_col7, #T_0e683_row5_col7, #T_0e683_row7_col3, #T_0e683_row7_col5 {
#   background-color: #3480b9;
#   color: #f1f1f1;
# }
# #T_0e683_row4_col5, #T_0e683_row5_col4 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_0e683_row4_col6, #T_0e683_row6_col4 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_0e683_row4_col7, #T_0e683_row7_col4 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# </style>
# <table id="T_0e683_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Process Size (nm)</th>
#       <th class="col_heading level0 col1" >TDP (W)</th>
#       <th class="col_heading level0 col2" >Die Size (mm^2)</th>
#       <th class="col_heading level0 col3" >Transistors (million)</th>
#       <th class="col_heading level0 col4" >Freq (MHz)</th>
#       <th class="col_heading level0 col5" >FP16 GFLOPS</th>
#       <th class="col_heading level0 col6" >FP32 GFLOPS</th>
#       <th class="col_heading level0 col7" >FP64 GFLOPS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e683_level0_row0" class="row_heading level0 row0" >Process Size (nm)</th>
#       <td id="T_0e683_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_0e683_row0_col1" class="data row0 col1" >-0.199</td>
#       <td id="T_0e683_row0_col2" class="data row0 col2" >-0.270</td>
#       <td id="T_0e683_row0_col3" class="data row0 col3" >-0.412</td>
#       <td id="T_0e683_row0_col4" class="data row0 col4" >-0.667</td>
#       <td id="T_0e683_row0_col5" class="data row0 col5" >-0.369</td>
#       <td id="T_0e683_row0_col6" class="data row0 col6" >-0.466</td>
#       <td id="T_0e683_row0_col7" class="data row0 col7" >-0.216</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row1" class="row_heading level0 row1" >TDP (W)</th>
#       <td id="T_0e683_row1_col0" class="data row1 col0" >-0.199</td>
#       <td id="T_0e683_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_0e683_row1_col2" class="data row1 col2" >0.731</td>
#       <td id="T_0e683_row1_col3" class="data row1 col3" >0.478</td>
#       <td id="T_0e683_row1_col4" class="data row1 col4" >0.420</td>
#       <td id="T_0e683_row1_col5" class="data row1 col5" >0.649</td>
#       <td id="T_0e683_row1_col6" class="data row1 col6" >0.517</td>
#       <td id="T_0e683_row1_col7" class="data row1 col7" >0.392</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row2" class="row_heading level0 row2" >Die Size (mm^2)</th>
#       <td id="T_0e683_row2_col0" class="data row2 col0" >-0.270</td>
#       <td id="T_0e683_row2_col1" class="data row2 col1" >0.731</td>
#       <td id="T_0e683_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_0e683_row2_col3" class="data row2 col3" >0.694</td>
#       <td id="T_0e683_row2_col4" class="data row2 col4" >0.378</td>
#       <td id="T_0e683_row2_col5" class="data row2 col5" >0.692</td>
#       <td id="T_0e683_row2_col6" class="data row2 col6" >0.653</td>
#       <td id="T_0e683_row2_col7" class="data row2 col7" >0.558</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row3" class="row_heading level0 row3" >Transistors (million)</th>
#       <td id="T_0e683_row3_col0" class="data row3 col0" >-0.412</td>
#       <td id="T_0e683_row3_col1" class="data row3 col1" >0.478</td>
#       <td id="T_0e683_row3_col2" class="data row3 col2" >0.694</td>
#       <td id="T_0e683_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_0e683_row3_col4" class="data row3 col4" >0.527</td>
#       <td id="T_0e683_row3_col5" class="data row3 col5" >0.810</td>
#       <td id="T_0e683_row3_col6" class="data row3 col6" >0.862</td>
#       <td id="T_0e683_row3_col7" class="data row3 col7" >0.685</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row4" class="row_heading level0 row4" >Freq (MHz)</th>
#       <td id="T_0e683_row4_col0" class="data row4 col0" >-0.667</td>
#       <td id="T_0e683_row4_col1" class="data row4 col1" >0.420</td>
#       <td id="T_0e683_row4_col2" class="data row4 col2" >0.378</td>
#       <td id="T_0e683_row4_col3" class="data row4 col3" >0.527</td>
#       <td id="T_0e683_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_0e683_row4_col5" class="data row4 col5" >0.276</td>
#       <td id="T_0e683_row4_col6" class="data row4 col6" >0.582</td>
#       <td id="T_0e683_row4_col7" class="data row4 col7" >0.190</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row5" class="row_heading level0 row5" >FP16 GFLOPS</th>
#       <td id="T_0e683_row5_col0" class="data row5 col0" >-0.369</td>
#       <td id="T_0e683_row5_col1" class="data row5 col1" >0.649</td>
#       <td id="T_0e683_row5_col2" class="data row5 col2" >0.692</td>
#       <td id="T_0e683_row5_col3" class="data row5 col3" >0.810</td>
#       <td id="T_0e683_row5_col4" class="data row5 col4" >0.276</td>
#       <td id="T_0e683_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_0e683_row5_col6" class="data row5 col6" >0.728</td>
#       <td id="T_0e683_row5_col7" class="data row5 col7" >0.683</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row6" class="row_heading level0 row6" >FP32 GFLOPS</th>
#       <td id="T_0e683_row6_col0" class="data row6 col0" >-0.466</td>
#       <td id="T_0e683_row6_col1" class="data row6 col1" >0.517</td>
#       <td id="T_0e683_row6_col2" class="data row6 col2" >0.653</td>
#       <td id="T_0e683_row6_col3" class="data row6 col3" >0.862</td>
#       <td id="T_0e683_row6_col4" class="data row6 col4" >0.582</td>
#       <td id="T_0e683_row6_col5" class="data row6 col5" >0.728</td>
#       <td id="T_0e683_row6_col6" class="data row6 col6" >1.000</td>
#       <td id="T_0e683_row6_col7" class="data row6 col7" >0.520</td>
#     </tr>
#     <tr>
#       <th id="T_0e683_level0_row7" class="row_heading level0 row7" >FP64 GFLOPS</th>
#       <td id="T_0e683_row7_col0" class="data row7 col0" >-0.216</td>
#       <td id="T_0e683_row7_col1" class="data row7 col1" >0.392</td>
#       <td id="T_0e683_row7_col2" class="data row7 col2" >0.558<

# %%
# data normalization for CPU dataset
from sklearn.preprocessing import MinMaxScaler
CPU_normal = CPU.copy().drop(columns=['Product','Type','Foundry','Vendor'])
scaler = MinMaxScaler()
scaler.fit(CPU_normal)
fit = scaler.fit_transform(CPU_normal)
# fit = pd.DataFrame(fit, columns = CPU_normal.columns)
final = pd.DataFrame(data = fit, columns = CPU_normal.columns, index = CPU_normal.index)
CPU_normal = CPU.copy().drop(columns=CPU_normal.columns).join(final)
CPU_normal
# Out:
#                         Product Type  Foundry Vendor  Release Date  \
# 0           AMD Athlon 64 3500+  CPU  Unknown    AMD      0.321634
# 1              AMD Athlon 200GE  CPU  Unknown    AMD      0.875211
# 2          Intel Core i5-1145G7  CPU    Intel  Intel      0.970584
# 3         Intel Xeon E5-2603 v2  CPU    Intel  Intel      0.634806
# 4       AMD Phenom II X4 980 BE  CPU  Unknown    AMD      0.523187
# ...                         ...  ...      ...    ...           ...
# 2187      Intel Xeon Gold 6312U  CPU    Intel  Intel      0.999080
# 2188          AMD Ryzen 9 4900H  CPU     TSMC    AMD      0.948449
# 2189     Intel Core 2 Duo E6550  CPU    Intel  Intel      0.339117
# 2190            AMD Opteron 246  CPU  Unknown    AMD      0.215248
# 2191  AMD Athlon 64 X2 5000+ EE  CPU  Unknown    AMD      0.319138
#
#       Process Size (nm)   TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 0              0.335260  0.110276         0.111274               0.004436
# 1              0.040462  0.085213         0.279649               0.248552
# 2              0.017341  0.067669              NaN                    NaN
# 3              0.086705  0.197995         0.232796               0.071127
# 4              0.219653  0.310777         0.376281               0.037625
# ...                 ...       ...              ...                    ...
# 2187           0.017341  0.461153              NaN                    NaN
# 2188           0.000000  0.132832         0.226940               0.509471
# 2189           0.335260  0.160401         0.207906               0.013255
# 2190           0.479769  0.210526              NaN               0.003601
# 2191           0.479769  0.160401         0.320644               0.006106
#
#       Freq (MHz)
# 0       0.390244
# 1       0.634146
# 2       0.487805
# 3       0.292683
# 4       0.756098
# ...          ...
# 2187    0.439024
# 2188    0.658537
# 2189    0.422683
# 2190    0.341463
# 2191    0.487805
#
# [2192 rows x 10 columns]

# %%
#data normalization for GPU dataset
from sklearn.preprocessing import MinMaxScaler
GPU_normal = GPU.copy().drop(columns=['Product','Type','Foundry','Vendor'])
scaler = MinMaxScaler()
scaler.fit(GPU_normal)
fit = scaler.fit_transform(GPU_normal)

#add back to the dataframe
final = pd.DataFrame(data = fit, columns = GPU_normal.columns, index = GPU_normal.index)
#GPU_normal = GPU.copy().drop(columns=GPU_normal.columns).join(final)
GPU_normal
# Out:
#      Release Date  Process Size (nm)  TDP (W)  Die Size (mm^2)  \
# 2192    11.341553               32.0     95.0            216.0
# 2193     2.568493              150.0      NaN            174.0
# 2194     19.22968               14.0     25.0            132.0
# 2195     8.255479              130.0      NaN              NaN
# 2196     8.832192               55.0     20.0             73.0
# ...           ...                ...      ...              ...
# 4849    11.226941               40.0     75.0            332.0
# 4850      5.50274               90.0      7.0              NaN
# 4851    10.258219               40.0     23.0            100.0
# 4852     3.266438              150.0      NaN             65.0
# 4853      8.50274               65.0      NaN             86.0
#
#       Transistors (million)  Freq (MHz)  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 2192                 1160.0       100.0          NaN          NaN          NaN
# 2193                   80.0       200.0          NaN          NaN          NaN
# 2194                 3300.0      1469.0        18.38       1177.0        36.77
# 2195                    NaN       200.0          NaN         12.8          NaN
# 2196                  242.0       600.0          NaN         96.0          NaN
# ...                     ...         ...          ...          ...          ...
# 4849                 1950.0       450.0          NaN        432.0        36.00
# 4850                    NaN       250.0          NaN          NaN          NaN
# 4851                  486.0       500.0          NaN         52.8          NaN
# 4852                   29.0       250.0          NaN          NaN          NaN
# 4853                  210.0       540.0          NaN         20.8          NaN
#
# [2662 rows x 9 columns]

# %%
display(CPU.Foundry.unique())
display(CPU.Vendor.unique())
display(GPU.Foundry.unique())
display(GPU.Vendor.unique())
# Out:
# array(['Unknown', 'Intel', 'GF', 'TSMC'], dtype=object)
# array(['AMD', 'Intel'], dtype=object)
# array(['Intel', 'UMC', 'Samsung', 'TSMC', 'Unknown', 'Renesas', 'GF',
#        'Sony', 'NEC', 'IBM'], dtype=object)
# array(['Intel', 'Other', 'NVIDIA', 'ATI', 'AMD'], dtype=object)

# %% [markdown]
# We found there are mainly four different Foundry of the CPU and with the Vendors are AMD and Intel. The Foundry of GPU are Intel UMC Samsung TSMC Renesas GF Sony NEC and IBM, the Vendor are mainly in Intel NVIDIA ATI and AMD.
#
# We found there are high correlation between this two variable,(A single Foundry usually only hs one corresponding Vendor.So next we will be focus more on Vendor and we will replace the name of it to the number for ml.

# %%
CPU['Vendor'] = CPU['Vendor'].replace(['AMD', 'Intel'], ['0', '1'])
GPU['Vendor'] = GPU['Vendor'].replace(['AMD', 'Intel', 'Other', 'NVIDIA', 'ATI'], ['0', '1','2','3','4'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
